# %%
import pandas as pd
import os
import json
import zipfile
import matplotlib.pyplot as plt
import numpy as np

kaggle_dir = os.path.expanduser("~/.kaggle")
os.makedirs(kaggle_dir, exist_ok=True)
kaggle_api_token = "enter_token" # Assuming this is the key, excluding the 'KGAT_' prefix
kaggle_username = "raunaqmittal2004"

# Create kaggle.json
kaggle_dir = os.path.expanduser("~/.kaggle")
os.makedirs(kaggle_dir, exist_ok=True)

kaggle_json_path = os.path.join(kaggle_dir, "kaggle.json")
with open(kaggle_json_path, "w") as f:
    json.dump({"username": kaggle_username, "key": kaggle_api_token}, f)

# On Linux/Mac you can set permissions, skip on Windows
try:
    os.chmod(kaggle_json_path, 0o600)
except:
    pass

# Download dataset if not already extracted
if not os.path.exists("data.csv"):
    # !pip install -q kaggle
    # !kaggle datasets download -d shrutibhargava94/india-air-quality-data -p .
    
    with zipfile.ZipFile("india-air-quality-data.zip", "r") as zip_ref:
        zip_ref.extractall(".")

df = pd.read_csv("data.csv", encoding="latin-1")
df.head()
# Out:
# C:\Users\rauna\AppData\Local\Temp\ipykernel_12312\2844922548.py:40: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data.csv", encoding="latin-1")
#   stn_code       sampling_date           state   location agency  \
# 0    150.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1    151.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2    152.0  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3    150.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4    151.0     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# ...

# %%
df.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %%
x = df['no2'].dropna().values

# %%
r = 102303752
# Computing ar and br
print("r % 7 =", r % 7)
print("r % 5 =", r % 5)

ar = 0.05 * (r % 7)
br = 0.3 * (r % 5 + 1)

ar, br
# Out:
# r % 7 = 5
# r % 5 = 2
# (0.25, 0.8999999999999999)

# %%
# Apply transformation
z = x + ar * np.sin(br * x)

# %%
# Step 2
# Calculating mean
mu = np.mean(z)
# Calculating Lambda variance
variance = np.mean((z - mu) ** 2)
lambda_ = 1 / (2 * variance)
c = np.sqrt(lambda_ / np.pi)
print("mu =", mu)
print("lambda =", lambda_)
print("c =", c)
# Out:
# mu = 25.802708360471062
# lambda = 0.0014590905290116402
# c = 0.021550938267777164

# %%
z_shuffled = np.random.permutation(z)
mu2 = np.mean(z_shuffled)
var2 = np.mean((z_shuffled - mu2)**2)
lambda2 = 1 / (2 * var2)
c2 = np.sqrt(lambda2 / np.pi)
mu2, lambda2, c2
# Out:
# (np.float64(25.802708360471055),
#  np.float64(0.0014590905290116402),
#  np.float64(0.021550938267777164))
